# %%
# Q1. What is anomaly detection and what is its purpose?

# %%
# Anomaly detection is a technique used to identify unusual or unexpected patterns in data that differ significantly from 
# the majority of the data. These unusual patterns are referred to as anomalies or outliers.

# Purpose:
# Fraud Detection: Identifying fraudulent activities in financial transactions or credit card usage.
# Network Security: Detecting unauthorized access or cyber-attacks in network traffic.
# Fault Detection: Identifying defects or malfunctions in industrial equipment or machinery.
# Quality Control: Monitoring and maintaining product quality in manufacturing processes.
# Health Monitoring: Detecting abnormal health conditions or disease outbreaks based on medical data.

# %%
# Q2. What are the key challenges in anomaly detection?

# %%
# 1.High Dimensionality
# 2.Imbalanced Data
# 3.Defining What Constitutes Anomalies
# 4.Dynamic Nature of Anomalies
# 5.Noise and Outliers
# 6.Scalability
# 7.Model Interpretability

# %%
# Q3. How does unsupervised anomaly detection differ from supervised anomaly detection?

# %%
# Unsupervised anomaly detection is used when you don't have labeled data, and the goal is to identify unusual patterns or
# structures in the data. Supervised anomaly detection is used when you have labeled data, and the goal is to learn a model 
# that can accurately classify new instances as anomalies or normal behavior

# %%
# Q4. What are the main categories of anomaly detection algorithms?

# %%
# 1. Statistical-Based Methods
# These methods assume a statistical model for the data and identify anomalies as data points that are unlikely to be 
# generated by the model.
# Examples: Z-score method, Modified Z-score method, Chi-square method

# 2. Machine Learning-Based Methods
# These methods use machine learning algorithms to learn the patterns in the data and identify anomalies.
# Examples: One-Class SVM, Local Outlier Factor (LOF), Isolation Forest

# 3. Distance-Based Methods
# These methods calculate the distance between data points and identify anomalies as points that are farthest from the rest.
# Examples: k-Nearest Neighbors (k-NN), k-Means

# 7. Graph-Based Methods
# These methods are used for anomaly detection in graph-structured data, such as social networks or web graphs.
# Examples: Graph-Based Anomaly Detection (GBAD

# %%
# Q5. What are the main assumptions made by distance-based anomaly detection methods?

# %%
# Normal data is dense and close together
# Anomalies are sparse, isolated, and far from normal data
# The chosen distance metric is meaningful
# Data is uniformly distributed
# Anomalies are not clustered
# Normal data is not noisy
# A clear distance threshold can be defined

# %%
# Q6. How does the LOF algorithm compute anomaly scores?

# %%
# k-Nearest Neighbors: Identify the k nearest neighbors of each data point.
# Reachability Distance: Measure the reachability distance to avoid outliers having too much influence.
# Local Reachability Density (LRD): Calculate the local density of each point based on reachability distances.
# LOF Score: Compare the LRD of a point to its neighbors to compute the LOF score.

# Interpretation:
# LOF ≈ 1: Normal point with density similar to neighbors.
# LOF > 1: Potential outlier with lower density than neighbors.
# LOF < 1: Less likely to be an outlier, in a denser region.

# %%
# Q7. What are the key parameters of the Isolation Forest algorithm?

# %%
# n_estimators: Number of isolation trees in the forest.
# max_samples: Number of samples used to train each tree.
# max_features: Number of features considered for splitting nodes in each tree.
# contamination: Proportion of expected outliers in the dataset.
# random_state: Controls the randomness to ensure reproducibility.

# %%
# Q8. If a data point has only 2 neighbours of the same class within a radius of 0.5, what is its anomaly score
# using KNN with K=10?

# %%
# Anomaly score = 0.8

# %%
# Q9. Using the Isolation Forest algorithm with 100 trees and a dataset of 3000 data points, what is the
# anomaly score for a data point that has an average path length of 5.0 compared to the average path
# length of the trees?

# %%
# The anomaly score of approximately 0.776 suggests that the data point is relatively normal. In the Isolation Forest
# algorithm, scores closer to 1 indicate anomalies, while scores closer to 0 indicate normal points.
