# %%
import pandas as pd
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [raw]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %% [raw]
# Ans: The wine quality dataset typically includes the following key features:
#
# Fixed Acidity: Non-volatile acids contributing to tartness and structure.
# Volatile Acidity: Volatile acids like acetic acid, affecting flavor negatively if high.
# Citric Acid: Adds freshness and enhances fruity flavors.
# Residual Sugar: Determines sweetness, balancing acidity.
# Chlorides: Contribute to salty flavors; high levels indicate poor practices.
# Free Sulfur Dioxide: Protects against oxidation and spoilage.
# Total Sulfur Dioxide: Includes all forms of sulfur dioxide, crucial for stability.
# Density: Related to alcohol content and sweetness, affecting body and texture.
# pH: Measures acidity/basicity, influencing taste and stability.
# Sulphates: Additives that contribute to longevity and aroma complexity.
# Alcohol: Affects body, sweetness perception, and warmth.

# %% [raw]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %% [raw]
# Handling missing data involves various techniques, each with its advantages and disadvantages:
#
# Removing Rows/Columns:
# Advantages: Simple and avoids bias from imputed values.
# Disadvantages: Can lead to data loss and potential bias.
#
# Mean/Median/Mode Imputation:
# Advantages: Easy and quick, preserves dataset size.
# Disadvantages: Can introduce bias and distort variance and relationships.
#
# Forward/Backward Fill:
# Advantages: Useful for time-series data, simple.
# Disadvantages: Can propagate errors, assumes similarity with neighbors.
#
# Interpolation:
# Advantages: More accurate for time-series data.
# Disadvantages: Computationally intensive, may introduce bias.
#
# Using Machine Learning Algorithms:
# Advantages: Captures complex relationships, often more accurate.
# Disadvantages: Requires significant computational resources, risk of overfitting.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the dataset
df = pd.read_csv('stud.csv')
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [raw]
# Key Factors Affecting Performance:
# Socioeconomic Status (SES): Family income, parental education, and occupation.
# Study Habits: Time spent studying, study methods, and consistency.
# School Environment: Teacher quality, classroom size, and school facilities.
# Personal Factors: Health, sleep patterns, stress levels, and motivation.
# Attendance: Regularity and punctuality.
# Parental Involvement: Level of engagement and support from parents.
# Extracurricular Activities: Participation in sports, arts, etc.

# %% [raw]
# Steps to Analyze Factors:
# Data Cleaning and Preparation:
#
# Handle missing data and convert categorical variables to numerical values.
# Exploratory Data Analysis (EDA):
#
# Summary Statistics: Mean, median, mode, standard deviation.
# Visualization: Histograms, box plots, and scatter plots to understand data distribution.
# Correlation Analysis:
#
# Compute and visualize the correlation matrix to identify relationships.

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sns.pairplot(df)

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [raw]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %% [raw]
# Steps in Feature Engineering
# Data Cleaning:
#
# Handling Missing Values: Impute missing data using techniques like mean, median, or mode.
# Removing Outliers: Identify and remove or cap outliers.
# Feature Selection:
#
# Select relevant features based on domain knowledge and initial data analysis. Common features include study hours, attendance, parental education, health, and sleep hours.
# Feature Transformation:
#
# Normalization/Standardization: Scale numerical features to ensure they have similar ranges.
# Encoding Categorical Variables: Convert categorical variables into numerical values using techniques like one-hot encoding.
# Creating New Features:
# Interaction Terms: Create features representing the interaction between variables (e.g., study hours * attendance).
# Binning: Convert continuous variables into categorical ones by creating bins.
# Polynomial Features: Generate polynomial and interaction features to capture non-linear relationships.

# %%
df = df.dropna()

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [raw]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %% [raw]
# Load the Dataset:
#
# Import necessary libraries and load the wine quality dataset.
# Initial Exploration:
#
# Display the first few rows and summary statistics to understand the data.
# Visualize Distributions:
#
# Use histograms and boxplots to visualize the distribution of each feature.
#
# Identify Non-Normal Features:
# Inspect histograms and boxplots to identify features that exhibit non-normality.

# %%
df.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [raw]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
X = df.drop('quality', axis=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA()
pca.fit(X_scaled)
# Out:
# PCA()

# %%
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratio)
n_components = np.argmax(cumulative_variance >= 0.90) + 1

# %%
plt.figure(figsize=(8, 6))
plt.plot(cumulative_variance, marker='o', linestyle='--')
plt.axhline(y=0.90, color='r', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA - Explained Variance')
plt.grid(True)
plt.show()
